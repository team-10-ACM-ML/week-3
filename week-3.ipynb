# %%
import pandas as pd
import numpy as np

# %%
links = pd.read_csv(r"C:\Users\DELL\Desktop\ml-20m\links.csv")
links
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 27273   131254   466713    4436.0
# 27274   131256   277703    9274.0
# 27275   131258  3485166  285213.0
# 27276   131260   249110   32099.0
# 27277   131262  1724965  286971.0
#
# [27278 rows x 3 columns]

# %%
movies = pd.read_csv(r"C:\Users\DELL\Desktop\ml-20m\movies.csv")
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
ratings = pd.read_csv(r"C:\Users\DELL\Desktop\ml-20m\ratings.csv")
ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1        2     3.5  1112486027
# 1              1       29     3.5  1112484676
# 2              1       32     3.5  1112484819
# 3              1       47     3.5  1112484727
# 4              1       50     3.5  1112484580
# ...          ...      ...     ...         ...
# 20000258  138493    68954     4.5  1258126920
# 20000259  138493    69526     4.5  1259865108
# 20000260  138493    69644     3.0  1260209457
# 20000261  138493    70286     5.0  1258126944
# 20000262  138493    71619     2.5  1255811136
#
# [20000263 rows x 4 columns]

# %%
ratings.drop('timestamp',axis=1,inplace=True)
ratings
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]

# %%
data = pd.merge(ratings, movies, on = 'movieId')
data
# Out:
#           userId  movieId  rating  \
# 0              1        2     3.5
# 1              5        2     3.0
# 2             13        2     3.0
# 3             29        2     3.0
# 4             34        2     3.0
# ...          ...      ...     ...
# 20000258  138301   121017     3.5
# 20000259  138301   121019     4.5
# 20000260  138301   121021     4.5
# 20000261  138406   110167     4.5
# 20000262  138406   110510     4.5
#
#                                                       title  \
# 0                                            Jumanji (1995)
# 1                                            Jumanji (1995)
# 2                                            Jumanji (1995)
# 3                                            Jumanji (1995)
# 4                                            Jumanji (1995)
# ...                                                     ...
# 20000258                    The Gentleman from Epsom (1962)
# 20000259                         The Great Spy Chase (1964)
# ...

# %%
data.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'title', 'genres'], dtype='object')

# %%
a=data['userId'].value_counts()

# %%
b=data['userId'].value_counts()>500

# %%
new = list(a[b].index)

# %%
len(new)
# Out:
# 7441

# %%
data = data[data['userId'].isin(new)]

# %%
data.shape
# Out:
# (6554416, 5)

# %%
final = data.groupby('movieId')['rating'].count().reset_index()
final
# Out:
#        movieId  rating
# 0            1    6303
# 1            2    4610
# 2            3    2217
# 3            4     646
# 4            5    1973
# ...        ...     ...
# 26042   131254       1
# 26043   131256       1
# 26044   131258       1
# 26045   131260       1
# 26046   131262       1
#
# [26047 rows x 2 columns]

# %%
final = final[final['rating']>500]
final
# Out:
#        movieId  rating
# 0            1    6303
# 1            2    4610
# 2            3    2217
# 3            4     646
# 4            5    1973
# ...        ...     ...
# 22684   110102     546
# 22947   111362     598
# 23035   111759     649
# 23200   112556     539
# 23260   112852     704
#
# [3124 rows x 2 columns]

# %%
df = data[data['movieId'].isin(final.index)]
df
# Out:
#           userId  movieId  rating                                       title  \
# 5             54        2     3.0                              Jumanji (1995)
# 7             91        2     3.5                              Jumanji (1995)
# 8            116        2     2.0                              Jumanji (1995)
# 20           156        2     5.0                              Jumanji (1995)
# 31           251        2     4.0                              Jumanji (1995)
# ...          ...      ...     ...                                         ...
# 19990615  130767     6381     3.5  Three Marias, The (Três Marias, As) (2002)
# 19990616  134210     6381     4.0  Three Marias, The (Três Marias, As) (2002)
# 19993696   63147     3191     1.5                          Quarry, The (1998)
# 19993699  126395     3191     2.0                          Quarry, The (1998)
# 19993700  131904     3191     3.0                          Quarry, The (1998)
#
# ...

# %%
movie_pivot=df.pivot_table(columns='userId',index='title',values='rating')
movie_pivot
# Out:
# userId                                             11      24      54      \
# title
# 'burbs, The (1989)                                    NaN     NaN     3.0
# *batteries not included (1987)                        5.0     NaN     NaN
# ...All the Marbles (California Dolls, The) (1981)     NaN     NaN     NaN
# 1-900 (06) (1994)                                     NaN     NaN     NaN
# 10 Things I Hate About You (1999)                     5.0     NaN     NaN
# ...                                                   ...     ...     ...
# Zapped! (1982)                                        NaN     NaN     NaN
# Zero Kelvin (Kjærlighetens kjøtere) (1995)            NaN     NaN     NaN
# Ziggy Stardust and the Spiders from Mars (1973)       NaN     NaN     NaN
# eXistenZ (1999)                                       5.0     3.0     NaN
# À nous la liberté (Freedom for Us) (1931)             NaN     NaN     NaN
#
# ...

# %%
movie_pivot.fillna(0,inplace=True)
movie_pivot
# Out:
# userId                                             11      24      54      \
# title
# 'burbs, The (1989)                                    0.0     0.0     3.0
# *batteries not included (1987)                        5.0     0.0     0.0
# ...All the Marbles (California Dolls, The) (1981)     0.0     0.0     0.0
# 1-900 (06) (1994)                                     0.0     0.0     0.0
# 10 Things I Hate About You (1999)                     5.0     0.0     0.0
# ...                                                   ...     ...     ...
# Zapped! (1982)                                        0.0     0.0     0.0
# Zero Kelvin (Kjærlighetens kjøtere) (1995)            0.0     0.0     0.0
# Ziggy Stardust and the Spiders from Mars (1973)       0.0     0.0     0.0
# eXistenZ (1999)                                       5.0     3.0     0.0
# À nous la liberté (Freedom for Us) (1931)             0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix
movie_matrix=csr_matrix(movie_pivot)

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model=NearestNeighbors(algorithm='brute')

# %%
model.fit(movie_matrix)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
movie_pivot.iloc[1,:].values.reshape(1,-1)
# Out:
# array([[5., 0., 0., ..., 0., 0., 0.]])

# %%
distance,suggestion=model.kneighbors(movie_pivot.iloc[1,:].values.reshape(1,-1),n_neighbors=5)

# %%
suggestion
# Out:
# array([[   1, 2399,  392, 1438, 2488]], dtype=int64)

# %%
movie_pivot.index[392]
# Out:
# 'C.H.U.D. II - Bud the Chud (1989)'

# %%
for i in suggestion[0]:
        print(movie_pivot.index[i])
# Out:
# *batteries not included (1987)
# Walk Like a Man (1987)
# C.H.U.D. II - Bud the Chud (1989)
# Man's Best Friend (1993)
# Yor, the Hunter from the Future (1983)

# %%
def recommend(moviename):
    m_id=np.where(movie_pivot.index==moviename)[0][0]
    distance,suggestion=model.kneighbors(movie_pivot.iloc[m_id,:].values.reshape(1,-1),n_neighbors=5)
    for i in suggestion[0]:
        print(movie_pivot.index[i])

# %%
recommend('10 Things I Hate About You (1999)')
# Out:
# 10 Things I Hate About You (1999)
# Bring It On (2000)
# Runaway Bride (1999)
# Save the Last Dance (2001)
# Wild Wild West (1999)

# %%
recommend('À nous la liberté (Freedom for Us) (1931)')
# Out:
# À nous la liberté (Freedom for Us) (1931)
# Bells, The (1926)
# Another Man's Poison (1952)
# Born to Win (1971)
# Cowboy (1958)
